# %% [markdown]
# ## Linear Algebra
#
#
# ### 1. Projection Matrices
#
# Given :
#
# $$ P = X(XX')^{-1}X' ,   \quad   M = I_n - P $$
#
# Use:
#
#
# $$ y = X \beta + e  , \quad \hat{\beta} = (XX')^{-1}X'y $$

# %% [markdown]
# #### a.  P is idempotent (PP = P)
#
#
# $$  PP = X(XX')^{-1}X'X(XX')^{-1}X'  =  XI(XX')^{-1}X' $$
#
# $$ PP = X(X'X)^{-1}X' $$
#
# $$ PP = P $$

# %% [markdown]
# #### b.  M is idempotent (MM = M)
#
# $$ MM = (I_n - P) ( I_n - P)  \quad = I_n - 2P + PP \quad = I_n - 2P + P $$
#
# $$ MM = M $$

# %% [markdown]
# #### c. Py = $\hat{y}$
#
# $$ Py = X(X'X)^{-1}X'y $$
#
# $$ Py = X \hat{\beta} $$
#
# $$ Py = \hat{y} $$

# %% [markdown]
# #### d. My = $\hat{e}$
#
# $$ (I_n - P)y \quad = y - Py \quad = y - \hat{y} $$
#
# $$ My = \hat{e} $$

# %% [markdown]
# #### e. $\hat{y} \bot \hat{e}$
#
#
#
# $$ \hat{y}. \hat{e} = 0 $$
#
#
# $$ (Py).(My) = (Py^2)(I_n - P)$$
# $$ = Py^2 - PPy^2$$
# $$ = Py^2 - Py^2 \ (Since \ P \ is \ idempotent)$$
# $$ (Py).(My) = 0$$
# Hence, proved

# %% [markdown]
# ## Question 2
#
# #### Generalized hailstone numbers ####

# %%
def hailstone(a, b, max_iter):
    holding = []

    for i in range(1, max_iter):
        seq = []
        print("--- Initial number =", i)

        while i >= 1:
            seq.append(i)
            count_dict = {}

            for n in seq:
                count_dict[n] = count_dict.get(n, 0) + 1

            max_num = max(count_dict, key=count_dict.get)
            max_count = count_dict[max_num]

            ind = seq.index(max_num)
            holding = seq[ind:]

            if i % 2 == 0:
                i //= 2
            else:
                i = a * i + b

            if len(seq) > 50:
                print("No Convergence")
                break

        if len(seq) != len(set(seq)):
            holding.append((len(seq), holding))
            print("Sequence consists", len(seq), "steps")
            print("Holding pattern:", holding)

    print("Total holding patterns:", len(holding))

# %%
for a in range(1, 11):
    for b in range(1, 11):
        print('--> When a = ' + str(a) + ', and b = ' + str(b))
        hailstone(a, b, 100)
# Out:
# --> When a = 1, and b = 1
# --- Initial number = 1
# No Convergence
# Sequence consists 51 steps
# Holding pattern: [1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, (51, [...])]
# --- Initial number = 2
# No Convergence
# Sequence consists 51 steps
# Holding pattern: [2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, (51, [...])]
# --- Initial number = 3
# No Convergence
# Sequence consists 51 steps
# Holding pattern: [2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, (51, [...])]
# --- Initial number = 4
# No Convergence
# Sequence consists 51 steps
# ...
